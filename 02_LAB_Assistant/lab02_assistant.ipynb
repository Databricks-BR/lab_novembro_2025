# %% [markdown]
# <img src="https://raw.githubusercontent.com/Databricks-BR/lab_agosto_2025/main/images/head_lab.png">
#
# ## LAB 02 - Entendendo os dados com o Assistant
#
# 1. Na célula 6, troque `catalogo` pelo valor do `catalog_name` e troque `schema`pelo valor do `schema_name`
# 2. Selecione o Cluster a ser utilizado
# 3. Clique em `Run All` ou `Executar tudo`

# %%
# Catálogo do Laboratório
catalog_name = f"dev_treinamento_databricks"
# Schema do Laboratório
schema_name  = f"gabriel_caballeria"

# %%
display(spark.sql(f"SHOW TABLES IN {catalog_name}.{schema_name}"))

# %% [markdown]
# ### Passo 1 - Perguntas abertas
#
# ### Como usar o Databricks Assistant:
#
# 1. Selecione e copie uma das perguntas abaixo.
# 2. Na célula 6, clique no ícone do Assistant ao lado da célula ou use o atalho `Ctrl + I` para abrir o Assistant.
# 3. Copie a pergunta no campo de texto do Assistant.
# 4. O Assistant irá sugerir código ou análise para responder à pergunta.
# 5. Execute o código sugerido para visualizar os resultados.

# %% [markdown]
# ## Perguntas
# - qual a quantidade de clientes inadimplentes?
# - valor da inadimplência por bairros?
# - valor total das faturas em aberto?
# - quantidade de faturas em aberto?
# - quantidade de faturas em aberto por aging da dívida?
# - quantidade de faturas em aberto por faixa de atraso?
# - quais os 10 bairros com maior quantidade de faturas em aberto com aging da divida a cima de 60 dias?

# %%
# %sql

SELECT * FROM dev_treinamento_databricks.gabriel_caballeria.faturamento
# Out:
# Databricks visualization. Run in Databricks to view.
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# # BÔNUS:
# No menu lateral do Assistant, faça a seguinte solicitação:
#
# Faça um estudo sobre todas as colunas da tabela faturamento e gere algumas análises
